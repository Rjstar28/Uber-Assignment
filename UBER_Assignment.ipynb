# %% [markdown]
# # Uber Assignment & Analysis

# %%
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# importing important libraries & modules
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns

# %%
# importing the database
df = pd.read_csv("Uber Request Data.csv")

# %%
# print first 10 lines to check if it's in correct format.
df.head(10)
# Out:
#    Request id Pickup point  Driver id          Status    Request timestamp  \
# 0         619      Airport        1.0  Trip Completed      11/7/2016 11:51
# 1         867      Airport        1.0  Trip Completed      11/7/2016 17:57
# 2        1807         City        1.0  Trip Completed       12/7/2016 9:17
# 3        2532      Airport        1.0  Trip Completed      12/7/2016 21:08
# 4        3112         City        1.0  Trip Completed  13-07-2016 08:33:16
# 5        3879      Airport        1.0  Trip Completed  13-07-2016 21:57:28
# 6        4270      Airport        1.0  Trip Completed  14-07-2016 06:15:32
# 7        5510      Airport        1.0  Trip Completed  15-07-2016 05:11:52
# 8        6248         City        1.0  Trip Completed  15-07-2016 17:57:27
# 9         267         City        2.0  Trip Completed       11/7/2016 6:46
#
#         Drop timestamp
# 0      11/7/2016 13:00
# 1      11/7/2016 18:47
# 2       12/7/2016 9:58
# 3      12/7/2016 22:03
# ...

# %%
# replacing coloumns name so we can use them appropriately.
df.columns = ['request_id',
 'pickup_point',
 'driver_id',
 'status',
 'request_timestamp',
 'drop_timestamp']

df.head()
# Out:
#    request_id pickup_point  driver_id          status    request_timestamp  \
# 0         619      Airport        1.0  Trip Completed      11/7/2016 11:51
# 1         867      Airport        1.0  Trip Completed      11/7/2016 17:57
# 2        1807         City        1.0  Trip Completed       12/7/2016 9:17
# 3        2532      Airport        1.0  Trip Completed      12/7/2016 21:08
# 4        3112         City        1.0  Trip Completed  13-07-2016 08:33:16
#
#         drop_timestamp
# 0      11/7/2016 13:00
# 1      11/7/2016 18:47
# 2       12/7/2016 9:58
# 3      12/7/2016 22:03
# 4  13-07-2016 09:25:47

# %%
df.isnull().sum()
# Out:
# request_id              0
# pickup_point            0
# driver_id            2650
# status                  0
# request_timestamp       0
# drop_timestamp       3914
# dtype: int64

# %%
# Checking relationship between null values, are they important for data analysis or not.!!

df[(df.driver_id.isnull()) & (df.status == "No Cars Available") & (df.drop_timestamp.isnull())]
# Out:
#       request_id pickup_point  driver_id             status  \
# 4095        1362         City        NaN  No Cars Available
# 4096        1364         City        NaN  No Cars Available
# 4097        1366         City        NaN  No Cars Available
# 4098           2      Airport        NaN  No Cars Available
# 4099           7      Airport        NaN  No Cars Available
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         request_timestamp drop_timestamp
# 4095       11/7/2016 0:02            NaN
# 4096       11/7/2016 0:06            NaN
# 4097       11/7/2016 0:09            NaN
# 4098       11/7/2016 0:23            NaN
# ...
